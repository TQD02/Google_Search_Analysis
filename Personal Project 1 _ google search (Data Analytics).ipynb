# %%
pip install pytrends
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq(hl="en-US")

trends.build_payload(kw_list = ["Data Analytics"])
data1 = trends.interest_by_region()
data1 = data1.sort_values(by = "Data Analytics", ascending = False)
sample_data1= data1.head(25)

# %%
sample_data1.reset_index().plot(x = "geoName",
                      y = "Data Analytics",
                      figsize = (15,15), kind = "bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data2 = trends.interest_over_time()
fig,ax = plt.subplots(figsize = (15,15))
data2["Data Analytics"].plot()
plt.style.use('fivethirtyeight')
plt.title("Total Google Searches for Data Analytics", fontweight = "bold")
plt.xlabel("Year")
plt.ylabel("Total Count")
plt.show()
